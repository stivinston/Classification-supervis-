# %% [markdown]
# ## Exercice 2 :Implementation d'un perceptron multicouche avec Pytorch

# %% [markdown]
# ### 1- Chargement des données

# %%
#Importation des bibliothèques
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ### Nature du dataset
# nous allons travaillés avec le dataset 'pima-indians-diabetes.csv' Il décrit les données des dossiers médicaux des Indiens Pima et indique s'ils ont présenté un diabète dans les cinq ans.
# Il s’agit d’un problème de classification binaire (apparition du diabète à 1 ou non à 0).

# %%
# Chargement du dataset
dataset = np.loadtxt('pima-indians-diabetes.csv', delimiter=',')
X = dataset[:,0:8]
y = dataset[:,8]

# %%
#Conversion des données en tenseurs Pytorch car PyTorch fonctionne généralement en virgule flottante 32 bits
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %% [markdown]
# ### 2- Architecture du modèle
# Pour cette modélisation, on prend en entrée des lignes de données à 08 variables. Ensuite nous allons utilisés un réseau entièrement connectés à 03 couches, chacune d'elle comportant respectivement 12, 8 et 1 neuronnes ainsi qu'une fonction d'activation à la sortie de chaque couche (ReLU, ReLU et Sigmoid). <br>
# On note qu'il existe deux différentes manière de construire un modèle. A l'aide de la méthode séquential (Celle que nous allons utiliser) et aussi en tant que classe héritée du module nn.Module qui est plus détaillée

# %%
model = nn.Sequential(
    nn.Linear(8, 12), #Définition de la 1ère couche dense avec 12 neuronnes en sortie
    nn.ReLU(), #Définition de la couche d'activation ReLU
    nn.Linear(12, 8), #Définition de la 1ère couche dense avec 08 neuronnes en sortie
    nn.ReLU(),
    nn.Linear(8, 1), #Définition de la 1ère couche dense avec 1 neuronne en sortie
    nn.Sigmoid())  #Définition de la couche d'activation Sigmoid

# %%
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=8, out_features=12, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=12, out_features=8, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=8, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %% [markdown]
# ## 4- Entrainement du modèle
# Entraîner un réseau signifie trouver le meilleur ensemble de pondérations pour mapper les entrées aux sorties de votre ensemble de données. La fonction de perte est la métrique permettant de mesurer la distance de la prédiction par rapport à la valeur réelle.  Dans cet xercicee,Nous allonsz utiliser l'entropie croisée binaire car il s'agit d'un problème de classification binaire <br>.L'optimiseur est l'algorithme qu'on utilise pour ajuster progressivement les poids du modèle afin de produire un meilleur résultat.Dans cet exercice nous utiliserons Adam qui est une version de la descente de gradient. <br>
# <br>
# Par la suite nous utiliserons différent optimiseur à savoir : NAdam, SGD et RMSprop afin de choisir le meilleur pour notre modèle.

# %%
model2 = model
model3 = model
model4 = model

# %%
loss_fn = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)
optimizer2 = optim.NAdam(model2.parameters(), lr=0.001)
optimizer3 = optim.SGD(model3.parameters(), lr=0.001)
optimizer4 = optim.RMSprop(model4.parameters(), lr=0.001)

# %%
n_epochs = 100
batch_size = 10
 
for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.2127651572227478
# Finished epoch 1, latest loss 0.21346750855445862
# Finished epoch 2, latest loss 0.21213948726654053
# Finished epoch 3, latest loss 0.21184664964675903
# Finished epoch 4, latest loss 0.2133508175611496
# Finished epoch 5, latest loss 0.21245479583740234
# Finished epoch 6, latest loss 0.21104201674461365
# Finished epoch 7, latest loss 0.21207137405872345
# Finished epoch 8, latest loss 0.21212908625602722
# Finished epoch 9, latest loss 0.2112291157245636
# Finished epoch 10, latest loss 0.2111547440290451
# Finished epoch 11, latest loss 0.21101966500282288
# Finished epoch 12, latest loss 0.21131205558776855
# Finished epoch 13, latest loss 0.21221059560775757
# Finished epoch 14, latest loss 0.21174533665180206
# Finished epoch 15, latest loss 0.21060894429683685
# Finished epoch 16, latest loss 0.21060077846050262
# Finished epoch 17, latest loss 0.2120809257030487
# Finished epoch 18, latest loss 0.2102530300617218
# Finished epoch 19, latest loss 0.21074925363063812
# Finished epoch 20, latest loss 0.21023984253406525
# Finished epoch 21, latest loss 0.21026231348514557
# Finished epoch 22, latest loss 0.210969477891922
# Finished epoch 23, latest loss 0.21208825707435608
# Finished epoch 24, latest loss 0.21091334521770477
# Finished epoch 25, latest loss 0.21053574979305267
# Finished epoch 26, latest loss 0.20907679200172424
# Finished epoch 27, latest loss 0.21025314927101135
# Finished epoch 28, latest loss 0.21027284860610962
# Finished epoch 29, latest loss 0.20953160524368286
# Finished epoch 30, latest loss 0.21041981875896454
# Finished epoch 31, latest loss 0.209318608045578
# Finished epoch 32, latest loss 0.20916272699832916
# Finished epoch 33, latest loss 0.21084681153297424
# Finished epoch 34, latest loss 0.20920853316783905
# Finished epoch 35, latest loss 0.2089332491159439
# Finished epoch 36, latest loss 0.20871976017951965
# Finished epoch 37, latest loss 0.20994442701339722
# Finished epoch 38, latest loss 0.20938390493392944
# Finished epoch 39, latest loss 0.20912332832813263
# Finished epoch 40, latest loss 0.20769831538200378
# Finished epoch 41, latest loss 0.20872391760349274
# Finished epoch 42, latest loss 0.21043823659420013
# Finished epoch 43, latest loss 0.20938408374786377
# Finished epoch 44, latest loss 0.2082981914281845
# Finished epoch 45, latest loss 0.20861177146434784
# Finished epoch 46, latest loss 0.20893846452236176
# Finished epoch 47, latest loss 0.20787470042705536
# Finished epoch 48, latest loss 0.20824551582336426
# Finished epoch 49, latest loss 0.20817603170871735
# Finished epoch 50, latest loss 0.20721592009067535
# Finished epoch 51, latest loss 0.2077856957912445
# Finished epoch 52, latest loss 0.20743347704410553
# Finished epoch 53, latest loss 0.2091628909111023
# Finished epoch 54, latest loss 0.20809513330459595
# Finished epoch 55, latest loss 0.20704735815525055
# Finished epoch 56, latest loss 0.2064194232225418
# Finished epoch 57, latest loss 0.2066381424665451
# Finished epoch 58, latest loss 0.20623190701007843
# Finished epoch 59, latest loss 0.206326425075531
# Finished epoch 60, latest loss 0.20794017612934113
# Finished epoch 61, latest loss 0.2078438252210617
# Finished epoch 62, latest loss 0.20656056702136993
# Finished epoch 63, latest loss 0.2074834704399109
# Finished epoch 64, latest loss 0.20672939717769623
# Finished epoch 65, latest loss 0.20516569912433624
# Finished epoch 66, latest loss 0.2069883942604065
# Finished epoch 67, latest loss 0.20615650713443756
# Finished epoch 68, latest loss 0.2069254219532013
# Finished epoch 69, latest loss 0.20662212371826172
# Finished epoch 70, latest loss 0.20728908479213715
# Finished epoch 71, latest loss 0.20737846195697784
# Finished epoch 72, latest loss 0.20559161901474
# Finished epoch 73, latest loss 0.20513473451137543
# Finished epoch 74, latest loss 0.2058178037405014
# Finished epoch 75, latest loss 0.20548146963119507
# Finished epoch 76, latest loss 0.20651952922344208
# Finished epoch 77, latest loss 0.2065441608428955
# Finished epoch 78, latest loss 0.20558588206768036
# Finished epoch 79, latest loss 0.20562437176704407
# Finished epoch 80, latest loss 0.20675690472126007
# Finished epoch 81, latest loss 0.20566220581531525
# Finished epoch 82, latest loss 0.20532077550888062
# Finished epoch 83, latest loss 0.2050420045852661
# Finished epoch 84, latest loss 0.20607031881809235
# Finished epoch 85, latest loss 0.2049241065979004
# Finished epoch 86, latest loss 0.20535974204540253
# Finished epoch 87, latest loss 0.20491217076778412
# Finished epoch 88, latest loss 0.20685455203056335
# Finished epoch 89, latest loss 0.20721577107906342
# Finished epoch 90, latest loss 0.2059251219034195
# Finished epoch 91, latest loss 0.2069421261548996
# Finished epoch 92, latest loss 0.20588749647140503
# Finished epoch 93, latest loss 0.20519962906837463
# Finished epoch 94, latest loss 0.2050997018814087
# Finished epoch 95, latest loss 0.20515911281108856
# Finished epoch 96, latest loss 0.2047608196735382
# Finished epoch 97, latest loss 0.20444455742835999
# Finished epoch 98, latest loss 0.20675019919872284
# Finished epoch 99, latest loss 0.20425334572792053

# %%
# compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model(X)
 
accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Accuracy 0.8059895634651184

# %%
n_epochs = 100
batch_size = 10
 
for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model2(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer2.zero_grad()
        loss.backward()
        optimizer2.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.21979360282421112
# Finished epoch 1, latest loss 0.219032421708107
# Finished epoch 2, latest loss 0.21872219443321228
# Finished epoch 3, latest loss 0.21882110834121704
# Finished epoch 4, latest loss 0.21879573166370392
# Finished epoch 5, latest loss 0.22310329973697662
# Finished epoch 6, latest loss 0.22139789164066315
# Finished epoch 7, latest loss 0.22340525686740875
# Finished epoch 8, latest loss 0.22174671292304993
# Finished epoch 9, latest loss 0.22286856174468994
# Finished epoch 10, latest loss 0.22111022472381592
# Finished epoch 11, latest loss 0.22006505727767944
# Finished epoch 12, latest loss 0.22123150527477264
# Finished epoch 13, latest loss 0.22051361203193665
# Finished epoch 14, latest loss 0.22028356790542603
# Finished epoch 15, latest loss 0.21939635276794434
# Finished epoch 16, latest loss 0.2203858643770218
# Finished epoch 17, latest loss 0.2186153680086136
# Finished epoch 18, latest loss 0.22632886469364166
# Finished epoch 19, latest loss 0.21901996433734894
# Finished epoch 20, latest loss 0.22679835557937622
# Finished epoch 21, latest loss 0.22517485916614532
# Finished epoch 22, latest loss 0.22651958465576172
# Finished epoch 23, latest loss 0.22530044615268707
# Finished epoch 24, latest loss 0.2245296686887741
# Finished epoch 25, latest loss 0.21914705634117126
# Finished epoch 26, latest loss 0.2180611491203308
# Finished epoch 27, latest loss 0.2178279459476471
# Finished epoch 28, latest loss 0.21683496236801147
# Finished epoch 29, latest loss 0.21629451215267181
# Finished epoch 30, latest loss 0.21760831773281097
# Finished epoch 31, latest loss 0.21781890094280243
# Finished epoch 32, latest loss 0.21693935990333557
# Finished epoch 33, latest loss 0.2157847136259079
# Finished epoch 34, latest loss 0.21642228960990906
# Finished epoch 35, latest loss 0.21599577367305756
# Finished epoch 36, latest loss 0.21559366583824158
# Finished epoch 37, latest loss 0.215413898229599
# Finished epoch 38, latest loss 0.21540798246860504
# Finished epoch 39, latest loss 0.21429070830345154
# Finished epoch 40, latest loss 0.2142346203327179
# Finished epoch 41, latest loss 0.2131173014640808
# Finished epoch 42, latest loss 0.2135474979877472
# Finished epoch 43, latest loss 0.21280637383460999
# Finished epoch 44, latest loss 0.2125685214996338
# Finished epoch 45, latest loss 0.21197327971458435
# Finished epoch 46, latest loss 0.21207812428474426
# Finished epoch 47, latest loss 0.2115049511194229
# Finished epoch 48, latest loss 0.21170519292354584
# Finished epoch 49, latest loss 0.21066050231456757
# Finished epoch 50, latest loss 0.2106044888496399
# Finished epoch 51, latest loss 0.21011924743652344
# Finished epoch 52, latest loss 0.20997558534145355
# Finished epoch 53, latest loss 0.20928238332271576
# Finished epoch 54, latest loss 0.2093791663646698
# Finished epoch 55, latest loss 0.21166789531707764
# Finished epoch 56, latest loss 0.21237358450889587
# Finished epoch 57, latest loss 0.2123701125383377
# Finished epoch 58, latest loss 0.21128779649734497
# Finished epoch 59, latest loss 0.21140256524085999
# Finished epoch 60, latest loss 0.2114032655954361
# Finished epoch 61, latest loss 0.20987150073051453
# Finished epoch 62, latest loss 0.2109466940164566
# Finished epoch 63, latest loss 0.2100546509027481
# Finished epoch 64, latest loss 0.2086527794599533
# Finished epoch 65, latest loss 0.20983248949050903
# Finished epoch 66, latest loss 0.20922347903251648
# Finished epoch 67, latest loss 0.20861129462718964
# Finished epoch 68, latest loss 0.20840130746364594
# Finished epoch 69, latest loss 0.20760346949100494
# Finished epoch 70, latest loss 0.2103128880262375
# Finished epoch 71, latest loss 0.20506803691387177
# Finished epoch 72, latest loss 0.20707979798316956
# Finished epoch 73, latest loss 0.20552238821983337
# Finished epoch 74, latest loss 0.20479989051818848
# Finished epoch 75, latest loss 0.20737186074256897
# Finished epoch 76, latest loss 0.20720341801643372
# Finished epoch 77, latest loss 0.2062351256608963
# Finished epoch 78, latest loss 0.2046111673116684
# Finished epoch 79, latest loss 0.20586152374744415
# Finished epoch 80, latest loss 0.2058108001947403
# Finished epoch 81, latest loss 0.20280210673809052
# Finished epoch 82, latest loss 0.20489293336868286
# Finished epoch 83, latest loss 0.20470355451107025
# Finished epoch 84, latest loss 0.201949343085289
# Finished epoch 85, latest loss 0.20316675305366516
# Finished epoch 86, latest loss 0.20298050343990326
# Finished epoch 87, latest loss 0.20251353085041046
# Finished epoch 88, latest loss 0.20145462453365326
# Finished epoch 89, latest loss 0.202377587556839
# Finished epoch 90, latest loss 0.20080219209194183
# Finished epoch 91, latest loss 0.2016790509223938
# Finished epoch 92, latest loss 0.20196810364723206
# Finished epoch 93, latest loss 0.201414555311203
# Finished epoch 94, latest loss 0.1995033472776413
# Finished epoch 95, latest loss 0.1995924562215805
# Finished epoch 96, latest loss 0.2023964375257492
# Finished epoch 97, latest loss 0.19855797290802002
# Finished epoch 98, latest loss 0.20236888527870178
# Finished epoch 99, latest loss 0.199510857462883

# %%
# compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model2(X)
 
accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Accuracy 0.8046875

# %%
n_epochs = 100
batch_size = 10
 
for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model3(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer3.zero_grad()
        loss.backward()
        optimizer3.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.20783618092536926
# Finished epoch 1, latest loss 0.20694586634635925
# Finished epoch 2, latest loss 0.20703276991844177
# Finished epoch 3, latest loss 0.20612740516662598
# Finished epoch 4, latest loss 0.20634645223617554
# Finished epoch 5, latest loss 0.2055206149816513
# Finished epoch 6, latest loss 0.2052391618490219
# Finished epoch 7, latest loss 0.20437517762184143
# Finished epoch 8, latest loss 0.20463527739048004
# Finished epoch 9, latest loss 0.20373345911502838
# Finished epoch 10, latest loss 0.2040114849805832
# Finished epoch 11, latest loss 0.2035192847251892
# Finished epoch 12, latest loss 0.20367605984210968
# Finished epoch 13, latest loss 0.20290890336036682
# Finished epoch 14, latest loss 0.20255185663700104
# Finished epoch 15, latest loss 0.20309287309646606
# Finished epoch 16, latest loss 0.2023225724697113
# Finished epoch 17, latest loss 0.2018287181854248
# Finished epoch 18, latest loss 0.20209942758083344
# Finished epoch 19, latest loss 0.2024201899766922
# Finished epoch 20, latest loss 0.20240651071071625
# Finished epoch 21, latest loss 0.2017732560634613
# Finished epoch 22, latest loss 0.20188403129577637
# Finished epoch 23, latest loss 0.20167849957942963
# Finished epoch 24, latest loss 0.20150358974933624
# Finished epoch 25, latest loss 0.20133887231349945
# Finished epoch 26, latest loss 0.20136955380439758
# Finished epoch 27, latest loss 0.20085471868515015
# Finished epoch 28, latest loss 0.200539693236351
# Finished epoch 29, latest loss 0.20162461698055267
# Finished epoch 30, latest loss 0.20041555166244507
# Finished epoch 31, latest loss 0.20109325647354126
# Finished epoch 32, latest loss 0.2014607936143875
# Finished epoch 33, latest loss 0.2006300538778305
# Finished epoch 34, latest loss 0.19954095780849457
# Finished epoch 35, latest loss 0.20012642443180084
# Finished epoch 36, latest loss 0.20058926939964294
# Finished epoch 37, latest loss 0.19995597004890442
# Finished epoch 38, latest loss 0.19957417249679565
# Finished epoch 39, latest loss 0.19968737661838531
# Finished epoch 40, latest loss 0.20005926489830017
# Finished epoch 41, latest loss 0.19975866377353668
# Finished epoch 42, latest loss 0.19886988401412964
# Finished epoch 43, latest loss 0.19936005771160126
# Finished epoch 44, latest loss 0.19910478591918945
# Finished epoch 45, latest loss 0.19878001511096954
# Finished epoch 46, latest loss 0.19906534254550934
# Finished epoch 47, latest loss 0.198862224817276
# Finished epoch 48, latest loss 0.19920742511749268
# Finished epoch 49, latest loss 0.19783936440944672
# Finished epoch 50, latest loss 0.1987166851758957
# Finished epoch 51, latest loss 0.1983187198638916
# Finished epoch 52, latest loss 0.19822755455970764
# Finished epoch 53, latest loss 0.198624849319458
# Finished epoch 54, latest loss 0.19746552407741547
# Finished epoch 55, latest loss 0.1975860297679901
# Finished epoch 56, latest loss 0.19866612553596497
# Finished epoch 57, latest loss 0.1974545270204544
# Finished epoch 58, latest loss 0.19856548309326172
# Finished epoch 59, latest loss 0.19750270247459412
# Finished epoch 60, latest loss 0.19782714545726776
# Finished epoch 61, latest loss 0.1980155110359192
# Finished epoch 62, latest loss 0.19815030694007874
# Finished epoch 63, latest loss 0.197474405169487
# Finished epoch 64, latest loss 0.19778187572956085
# Finished epoch 65, latest loss 0.19679394364356995
# Finished epoch 66, latest loss 0.19704823195934296
# Finished epoch 67, latest loss 0.19687756896018982
# Finished epoch 68, latest loss 0.19750238955020905
# Finished epoch 69, latest loss 0.19742068648338318
# Finished epoch 70, latest loss 0.19645357131958008
# Finished epoch 71, latest loss 0.1966969072818756
# Finished epoch 72, latest loss 0.1971237063407898
# Finished epoch 73, latest loss 0.19715000689029694
# Finished epoch 74, latest loss 0.19639621675014496
# Finished epoch 75, latest loss 0.19687092304229736
# Finished epoch 76, latest loss 0.19644573330879211
# Finished epoch 77, latest loss 0.19663573801517487
# Finished epoch 78, latest loss 0.19618751108646393
# Finished epoch 79, latest loss 0.19671902060508728
# Finished epoch 80, latest loss 0.19619297981262207
# Finished epoch 81, latest loss 0.1964515596628189
# Finished epoch 82, latest loss 0.19697123765945435
# Finished epoch 83, latest loss 0.19592896103858948
# Finished epoch 84, latest loss 0.19593331217765808
# Finished epoch 85, latest loss 0.19665765762329102
# Finished epoch 86, latest loss 0.19514472782611847
# Finished epoch 87, latest loss 0.19558651745319366
# Finished epoch 88, latest loss 0.19579556584358215
# Finished epoch 89, latest loss 0.1948796659708023
# Finished epoch 90, latest loss 0.19527548551559448
# Finished epoch 91, latest loss 0.19512450695037842
# Finished epoch 92, latest loss 0.19557449221611023
# Finished epoch 93, latest loss 0.19584016501903534
# Finished epoch 94, latest loss 0.1952076256275177
# Finished epoch 95, latest loss 0.19550780951976776
# Finished epoch 96, latest loss 0.19494205713272095
# Finished epoch 97, latest loss 0.19534337520599365
# Finished epoch 98, latest loss 0.1959269791841507
# Finished epoch 99, latest loss 0.19549532234668732

# %%
# compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model3(X)
 
accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Accuracy 0.8033854365348816

# %%
n_epochs = 100
batch_size = 10
 
for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model4(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer4.zero_grad()
        loss.backward()
        optimizer4.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.21114623546600342
# Finished epoch 1, latest loss 0.2025739550590515
# Finished epoch 2, latest loss 0.19799180328845978
# Finished epoch 3, latest loss 0.1967381089925766
# Finished epoch 4, latest loss 0.19469116628170013
# Finished epoch 5, latest loss 0.1946026235818863
# Finished epoch 6, latest loss 0.19344978034496307
# Finished epoch 7, latest loss 0.19270458817481995
# Finished epoch 8, latest loss 0.19421221315860748
# Finished epoch 9, latest loss 0.19153042137622833
# Finished epoch 10, latest loss 0.19283722341060638
# Finished epoch 11, latest loss 0.19009320437908173
# Finished epoch 12, latest loss 0.18941745162010193
# Finished epoch 13, latest loss 0.1884562373161316
# Finished epoch 14, latest loss 0.18883632123470306
# Finished epoch 15, latest loss 0.1900295466184616
# Finished epoch 16, latest loss 0.18988528847694397
# Finished epoch 17, latest loss 0.18893815577030182
# Finished epoch 18, latest loss 0.18943606317043304
# Finished epoch 19, latest loss 0.1885705292224884
# Finished epoch 20, latest loss 0.18823052942752838
# Finished epoch 21, latest loss 0.1881161630153656
# Finished epoch 22, latest loss 0.18809816241264343
# Finished epoch 23, latest loss 0.18724298477172852
# Finished epoch 24, latest loss 0.18701660633087158
# Finished epoch 25, latest loss 0.18665969371795654
# Finished epoch 26, latest loss 0.1858212798833847
# Finished epoch 27, latest loss 0.18525806069374084
# Finished epoch 28, latest loss 0.18392950296401978
# Finished epoch 29, latest loss 0.18411169946193695
# Finished epoch 30, latest loss 0.18462055921554565
# Finished epoch 31, latest loss 0.18499663472175598
# Finished epoch 32, latest loss 0.18314281105995178
# Finished epoch 33, latest loss 0.1841142326593399
# Finished epoch 34, latest loss 0.18395474553108215
# Finished epoch 35, latest loss 0.18293407559394836
# Finished epoch 36, latest loss 0.18328143656253815
# Finished epoch 37, latest loss 0.18216748535633087
# Finished epoch 38, latest loss 0.18282027542591095
# Finished epoch 39, latest loss 0.18218930065631866
# Finished epoch 40, latest loss 0.18200832605361938
# Finished epoch 41, latest loss 0.18215930461883545
# Finished epoch 42, latest loss 0.1815176010131836
# Finished epoch 43, latest loss 0.18128684163093567
# Finished epoch 44, latest loss 0.18183258175849915
# Finished epoch 45, latest loss 0.18184542655944824
# Finished epoch 46, latest loss 0.18049584329128265
# Finished epoch 47, latest loss 0.18018801510334015
# Finished epoch 48, latest loss 0.180303156375885
# Finished epoch 49, latest loss 0.18080569803714752
# Finished epoch 50, latest loss 0.17962294816970825
# Finished epoch 51, latest loss 0.1798960566520691
# Finished epoch 52, latest loss 0.17923274636268616
# Finished epoch 53, latest loss 0.17852914333343506
# Finished epoch 54, latest loss 0.17950095236301422
# Finished epoch 55, latest loss 0.1788748949766159
# Finished epoch 56, latest loss 0.17948265373706818
# Finished epoch 57, latest loss 0.17886026203632355
# Finished epoch 58, latest loss 0.17815090715885162
# Finished epoch 59, latest loss 0.17882128059864044
# Finished epoch 60, latest loss 0.17867127060890198
# Finished epoch 61, latest loss 0.1777755171060562
# Finished epoch 62, latest loss 0.17817941308021545
# Finished epoch 63, latest loss 0.17825818061828613
# Finished epoch 64, latest loss 0.1784152090549469
# Finished epoch 65, latest loss 0.17873990535736084
# Finished epoch 66, latest loss 0.17847687005996704
# Finished epoch 67, latest loss 0.1771324872970581
# Finished epoch 68, latest loss 0.17847013473510742
# Finished epoch 69, latest loss 0.17708756029605865
# Finished epoch 70, latest loss 0.176621213555336
# Finished epoch 71, latest loss 0.1764155775308609
# Finished epoch 72, latest loss 0.176712766289711
# Finished epoch 73, latest loss 0.17775674164295197
# Finished epoch 74, latest loss 0.17678989470005035
# Finished epoch 75, latest loss 0.17787767946720123
# Finished epoch 76, latest loss 0.1764802187681198
# Finished epoch 77, latest loss 0.17656749486923218
# Finished epoch 78, latest loss 0.17658759653568268
# Finished epoch 79, latest loss 0.17648299038410187
# Finished epoch 80, latest loss 0.17602072656154633
# Finished epoch 81, latest loss 0.17653734982013702
# Finished epoch 82, latest loss 0.17554013431072235
# Finished epoch 83, latest loss 0.1763068288564682
# Finished epoch 84, latest loss 0.17621950805187225
# Finished epoch 85, latest loss 0.1744014322757721
# Finished epoch 86, latest loss 0.1752161979675293
# Finished epoch 87, latest loss 0.17432430386543274
# Finished epoch 88, latest loss 0.1757255643606186
# Finished epoch 89, latest loss 0.1756521463394165
# Finished epoch 90, latest loss 0.17454469203948975
# Finished epoch 91, latest loss 0.17486044764518738
# Finished epoch 92, latest loss 0.17390918731689453
# Finished epoch 93, latest loss 0.1750529557466507
# Finished epoch 94, latest loss 0.17438501119613647
# Finished epoch 95, latest loss 0.17310799658298492
# Finished epoch 96, latest loss 0.17226484417915344
# Finished epoch 97, latest loss 0.17391319572925568
# Finished epoch 98, latest loss 0.1737145334482193
# Finished epoch 99, latest loss 0.17242436110973358

# %%
# compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model4(X)
 
accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Accuracy 0.8046875

# %% [markdown]
# ## 5- Evaluation des performances du modèle
# Avec les 04 optimiseurs (SGD, Adam, NAdam et RMSprop ) on obtient une précision de plus ou moins 80%. Donc on peut prendre position en disant que notre modèle est plutot bien entrainé, on ne peut pas avoir mieux que ce résultat

# %% [markdown]
# ## 6- Prediction
# En choisissant l'optimiseur Adam en définitif, nous allons prédire la classe(1 s'ils ont eu un diabète durant les 5 ans et 0 sinon ) de 5 individus au hasard. <br>
# On peut voir que 03 lignes sur 5 sont correctement prédites. De manière générale on doit s'attendre a ce que 80% des lignes soient correctement prédites du au performance estimé du modèle dans la section précedente

# %%
import random
# make class predictions with the model
predictions = (model(X) > 0.5).int()
nombres_aleatoires = [random.randint(0, 700) for _ in range(5)]
for i in nombres_aleatoires :
    print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [0.0, 161.0, 50.0, 0.0, 0.0, 21.899999618530273, 0.2540000081062317, 65.0] => 0 (expected 0)
# [7.0, 107.0, 74.0, 0.0, 0.0, 29.600000381469727, 0.2540000081062317, 31.0] => 0 (expected 1)
# [6.0, 166.0, 74.0, 0.0, 0.0, 26.600000381469727, 0.30399999022483826, 66.0] => 0 (expected 0)
# [10.0, 139.0, 80.0, 0.0, 0.0, 27.100000381469727, 1.440999984741211, 57.0] => 1 (expected 0)
# [3.0, 171.0, 72.0, 33.0, 135.0, 33.29999923706055, 0.19900000095367432, 24.0] => 1 (expected 1)
